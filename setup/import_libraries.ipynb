# %% [markdown]
# Shared imports for Adventure Works notebooks.
#
# Notebook purpose:
#
# * Centralize common PySpark type and function imports
# * Provide a single helper notebook that other notebooks can invoke with `%run`
#
# Keep this notebook minimal and update it only when shared imports are needed across multiple notebooks.

# %%
from pyspark.sql.types import * 
from pyspark.sql.functions import *
