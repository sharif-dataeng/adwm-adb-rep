# %%
# %run ./import_libraries

# %%
# HumanResources Schema Definitions

# humanresources.department
department_schema = StructType([
    StructField("DepartmentID", IntegerType(), False),
    StructField("Name", StringType(), False),
    StructField("GroupName", StringType(), False),
    StructField("ModifiedDate", TimestampType(), False)
])

# humanresources.shift
shift_schema = StructType([
    StructField("ShiftID", IntegerType(), False),
    StructField("Name", StringType(), False),
    StructField("StartTime", StringType(), False),
    StructField("EndTime", StringType(), False),
    StructField("ModifiedDate", TimestampType(), False)
])

# humanresources.employee
employee_schema = StructType([
    StructField("BusinessEntityID", IntegerType(), False),
    StructField("NationalIDNumber", StringType(), False),
    StructField("LoginID", StringType(), False),
    StructField("OrganizationNode", StringType(), True),
    StructField("JobTitle", StringType(), False),
    StructField("BirthDate", DateType(), False),
    StructField("MaritalStatus", StringType(), False),
    StructField("Gender", StringType(), False),
    StructField("HireDate", DateType(), False),
    StructField("SalariedFlag", BooleanType(), False),
    StructField("VacationHours", IntegerType(), False),
    StructField("SickLeaveHours", IntegerType(), False),
    StructField("CurrentFlag", BooleanType(), False),
    StructField("rowguid", StringType(), False),
    StructField("ModifiedDate", TimestampType(), False)
])

# humanresources.employeedepartmenthistory
employeedepartmenthistory_schema = StructType([
    StructField("BusinessEntityID", IntegerType(), False),
    StructField("DepartmentID", IntegerType(), False),
    StructField("ShiftID", IntegerType(), False),
    StructField("StartDate", DateType(), False),
    StructField("EndDate", DateType(), True),
    StructField("ModifiedDate", TimestampType(), False)
])

print("✓ HumanResources schemas defined")

# %%
# Person Schema Definitions

# person.businessentity
businessentity_schema = StructType([
    StructField("BusinessEntityID", IntegerType(), False),
    StructField("rowguid", StringType(), False),
    StructField("ModifiedDate", TimestampType(), False)
])

# person.person
person_schema = StructType([
    StructField("BusinessEntityID", IntegerType(), False),
    StructField("PersonType", StringType(), False),
    StructField("NameStyle", BooleanType(), False),
    StructField("Title", StringType(), True),
    StructField("FirstName", StringType(), False),
    StructField("MiddleName", StringType(), True),
    StructField("LastName", StringType(), False),
    StructField("Suffix", StringType(), True),
    StructField("EmailPromotion", IntegerType(), False),
    StructField("AdditionalContactInfo", StringType(), True),
    StructField("Demographics", StringType(), True),
    StructField("rowguid", StringType(), False),
    StructField("ModifiedDate", TimestampType(), False)
])

# person.addresstype
addresstype_schema = StructType([
    StructField("AddressTypeID", IntegerType(), False),
    StructField("Name", StringType(), False),
    StructField("rowguid", StringType(), False),
    StructField("ModifiedDate", TimestampType(), False)
])

# person.address
address_schema = StructType([
    StructField("AddressID", IntegerType(), False),
    StructField("AddressLine1", StringType(), False),
    StructField("AddressLine2", StringType(), True),
    StructField("City", StringType(), False),
    StructField("StateProvinceID", IntegerType(), False),
    StructField("PostalCode", StringType(), False),
    StructField("SpatialLocation", StringType(), True),
    StructField("rowguid", StringType(), False),
    StructField("ModifiedDate", TimestampType(), False)
])

# person.businessentityaddress
businessentityaddress_schema = StructType([
    StructField("BusinessEntityID", IntegerType(), False),
    StructField("AddressID", IntegerType(), False),
    StructField("AddressTypeID", IntegerType(), False),
    StructField("rowguid", StringType(), False),
    StructField("ModifiedDate", TimestampType(), False)
])

# person.stateprovince
stateprovince_schema = StructType([
    StructField("StateProvinceID", IntegerType(), False),
    StructField("StateProvinceCode", StringType(), False),
    StructField("CountryRegionCode", StringType(), False),
    StructField("IsOnlyStateProvinceFlag", BooleanType(), False),
    StructField("Name", StringType(), False),
    StructField("TerritoryID", IntegerType(), False),
    StructField("rowguid", StringType(), False),
    StructField("ModifiedDate", TimestampType(), False)
])

# person.countryregion
countryregion_schema = StructType([
    StructField("CountryRegionCode", StringType(), False),
    StructField("Name", StringType(), False),
    StructField("ModifiedDate", TimestampType(), False)
])

# person.emailaddress
emailaddress_schema = StructType([
    StructField("BusinessEntityID", IntegerType(), False),
    StructField("EmailAddressID", IntegerType(), False),
    StructField("EmailAddress", StringType(), True),
    StructField("rowguid", StringType(), False),
    StructField("ModifiedDate", TimestampType(), False)
])

# person.phonenumbertype
phonenumbertype_schema = StructType([
    StructField("PhoneNumberTypeID", IntegerType(), False),
    StructField("Name", StringType(), False),
    StructField("ModifiedDate", TimestampType(), False)
])

# person.personphone
personphone_schema = StructType([
    StructField("BusinessEntityID", IntegerType(), False),
    StructField("PhoneNumber", StringType(), False),
    StructField("PhoneNumberTypeID", IntegerType(), False),
    StructField("ModifiedDate", TimestampType(), False)
])

print("✓ Person schemas defined")

# %%
# Production Schema Definitions

# production.productcategory
productcategory_schema = StructType([
    StructField("ProductCategoryID", IntegerType(), False),
    StructField("Name", StringType(), False),
    StructField("rowguid", StringType(), False),
    StructField("ModifiedDate", TimestampType(), False)
])

# production.productsubcategory
productsubcategory_schema = StructType([
    StructField("ProductSubcategoryID", IntegerType(), False),
    StructField("ProductCategoryID", IntegerType(), False),
    StructField("Name", StringType(), False),
    StructField("rowguid", StringType(), False),
    StructField("ModifiedDate", TimestampType(), False)
])

# production.productmodel
productmodel_schema = StructType([
    StructField("ProductModelID", IntegerType(), False),
    StructField("Name", StringType(), False),
    StructField("CatalogDescription", StringType(), True),
    StructField("Instructions", StringType(), True),
    StructField("rowguid", StringType(), False),
    StructField("ModifiedDate", TimestampType(), False)
])

# production.product
product_schema = StructType([
    StructField("ProductID", IntegerType(), False),
    StructField("Name", StringType(), False),
    StructField("ProductNumber", StringType(), False),
    StructField("MakeFlag", BooleanType(), False),
    StructField("FinishedGoodsFlag", BooleanType(), False),
    StructField("Color", StringType(), True),
    StructField("SafetyStockLevel", IntegerType(), False),
    StructField("ReorderPoint", IntegerType(), False),
    StructField("StandardCost", DecimalType(19, 4), False),
    StructField("ListPrice", DecimalType(19, 4), False),
    StructField("Size", StringType(), True),
    StructField("SizeUnitMeasureCode", StringType(), True),
    StructField("WeightUnitMeasureCode", StringType(), True),
    StructField("Weight", DecimalType(8, 2), True),
    StructField("DaysToManufacture", IntegerType(), False),
    StructField("ProductLine", StringType(), True),
    StructField("Class", StringType(), True),
    StructField("Style", StringType(), True),
    StructField("ProductSubcategoryID", IntegerType(), True),
    StructField("ProductModelID", IntegerType(), True),
    StructField("SellStartDate", DateType(), False),
    StructField("SellEndDate", DateType(), True),
    StructField("DiscontinuedDate", DateType(), True),
    StructField("rowguid", StringType(), False),
    StructField("ModifiedDate", TimestampType(), False)
])

print("✓ Production schemas defined")

# %%
# Sales Schema Definitions

# sales.salesterritory
salesterritory_schema = StructType([
    StructField("TerritoryID", IntegerType(), False),
    StructField("Name", StringType(), False),
    StructField("CountryRegionCode", StringType(), False),
    StructField("Group", StringType(), False),
    StructField("SalesYTD", DecimalType(19, 4), False),
    StructField("SalesLastYear", DecimalType(19, 4), False),
    StructField("CostYTD", DecimalType(19, 4), False),
    StructField("CostLastYear", DecimalType(19, 4), False),
    StructField("rowguid", StringType(), False),
    StructField("ModifiedDate", TimestampType(), False)
])

# sales.customer
customer_schema = StructType([
    StructField("CustomerID", IntegerType(), False),
    StructField("PersonID", IntegerType(), True),
    StructField("StoreID", IntegerType(), True),
    StructField("TerritoryID", IntegerType(), True),
    StructField("AccountNumber", StringType(), False),
    StructField("rowguid", StringType(), False),
    StructField("ModifiedDate", TimestampType(), False)
])

print("✓ Sales schemas defined")

# %%
# Dimensional and Fact Table Schemas

# DimCustomer
dimcustomer_schema = StructType([
    StructField("CustomerKey", IntegerType(), False),
    StructField("CustomerID", IntegerType(), True),
    StructField("PersonID", IntegerType(), True),
    StructField("FirstName", StringType(), True),
    StructField("LastName", StringType(), True),
    StructField("FullName", StringType(), True),
    StructField("EmailAddress", StringType(), True),
    StructField("PhoneNumber", StringType(), True),
    StructField("AddressLine1", StringType(), True),
    StructField("City", StringType(), True),
    StructField("StateProvince", StringType(), True),
    StructField("CountryRegion", StringType(), True),
    StructField("PostalCode", StringType(), True),
    StructField("TerritoryID", IntegerType(), True),
    StructField("TerritoryName", StringType(), True),
    StructField("EffectiveDate", DateType(), True),
    StructField("ExpirationDate", DateType(), True),
    StructField("IsCurrent", BooleanType(), True)
])

# DimEmployee
dimemployee_schema = StructType([
    StructField("EmployeeKey", IntegerType(), False),
    StructField("BusinessEntityID", IntegerType(), True),
    StructField("NationalIDNumber", StringType(), True),
    StructField("LoginID", StringType(), True),
    StructField("FirstName", StringType(), True),
    StructField("LastName", StringType(), True),
    StructField("FullName", StringType(), True),
    StructField("JobTitle", StringType(), True),
    StructField("BirthDate", DateType(), True),
    StructField("MaritalStatus", StringType(), True),
    StructField("Gender", StringType(), True),
    StructField("HireDate", DateType(), True),
    StructField("DepartmentName", StringType(), True),
    StructField("GroupName", StringType(), True),
    StructField("EffectiveDate", DateType(), True),
    StructField("ExpirationDate", DateType(), True),
    StructField("IsCurrent", BooleanType(), True)
])

# DimProduct
dimproduct_schema = StructType([
    StructField("ProductKey", IntegerType(), False),
    StructField("ProductID", IntegerType(), True),
    StructField("ProductNumber", StringType(), True),
    StructField("ProductName", StringType(), True),
    StructField("Color", StringType(), True),
    StructField("Size", StringType(), True),
    StructField("StandardCost", DecimalType(19, 4), True),
    StructField("ListPrice", DecimalType(19, 4), True),
    StructField("ProductSubcategoryName", StringType(), True),
    StructField("ProductCategoryName", StringType(), True),
    StructField("ProductModelName", StringType(), True),
    StructField("SellStartDate", DateType(), True),
    StructField("SellEndDate", DateType(), True),
    StructField("EffectiveDate", DateType(), True),
    StructField("ExpirationDate", DateType(), True),
    StructField("IsCurrent", BooleanType(), True)
])

# FactSales
factsales_schema = StructType([
    StructField("SalesKey", LongType(), False),
    StructField("OrderDate", DateType(), False),
    StructField("DueDate", DateType(), True),
    StructField("ShipDate", DateType(), True),
    StructField("CustomerKey", IntegerType(), False),
    StructField("ProductKey", IntegerType(), False),
    StructField("EmployeeKey", IntegerType(), True),
    StructField("TerritoryID", IntegerType(), True),
    StructField("OrderQuantity", IntegerType(), False),
    StructField("UnitPrice", DecimalType(19, 4), False),
    StructField("UnitPriceDiscount", DecimalType(19, 4), True),
    StructField("LineTotal", DecimalType(38, 6), False),
    StructField("TaxAmt", DecimalType(19, 4), True),
    StructField("Freight", DecimalType(19, 4), True),
    StructField("TotalDue", DecimalType(19, 4), False)
])

# FactInventory
factinventory_schema = StructType([
    StructField("InventoryKey", LongType(), False),
    StructField("InventoryDate", DateType(), False),
    StructField("ProductKey", IntegerType(), False),
    StructField("LocationID", IntegerType(), False),
    StructField("Shelf", StringType(), True),
    StructField("Bin", IntegerType(), True),
    StructField("Quantity", IntegerType(), False),
    StructField("ModifiedDate", TimestampType(), True)
])

# FactProductionCost
factproductioncost_schema = StructType([
    StructField("ProductionCostKey", LongType(), False),
    StructField("ProductKey", IntegerType(), False),
    StructField("CostDate", DateType(), False),
    StructField("StandardCost", DecimalType(19, 4), False),
    StructField("ActualCost", DecimalType(19, 4), False),
    StructField("CostVariance", DecimalType(19, 4), True),
    StructField("ModifiedDate", TimestampType(), True)
])

print("✓ Dimensional and Fact table schemas defined")

# %%
# Schema Registry - Map table names to their schemas
schema_registry = {
    # HumanResources
    "humanresources.department": department_schema,
    "humanresources.employee": employee_schema,
    "humanresources.employeedepartmenthistory": employeedepartmenthistory_schema,
    "humanresources.shift": shift_schema,
    
    # Person
    "person.address": address_schema,
    "person.addresstype": addresstype_schema,
    "person.businessentity": businessentity_schema,
    "person.businessentityaddress": businessentityaddress_schema,
    "person.countryregion": countryregion_schema,
    "person.emailaddress": emailaddress_schema,
    "person.person": person_schema,
    "person.personphone": personphone_schema,
    "person.phonenumbertype": phonenumbertype_schema,
    "person.stateprovince": stateprovince_schema,
    
    # Production
    "production.product": product_schema,
    "production.productcategory": productcategory_schema,
    "production.productmodel": productmodel_schema,
    "production.productsubcategory": productsubcategory_schema,
    
    # Sales
    "sales.customer": customer_schema,
    "sales.salesterritory": salesterritory_schema,
    
    # Dimensional Tables
    "dimcustomer": dimcustomer_schema,
    "dimemployee": dimemployee_schema,
    "dimproduct": dimproduct_schema,
    
    # Fact Tables
    "factsales": factsales_schema,
    "factinventory": factinventory_schema,
    "factproductioncost": factproductioncost_schema
}

print(f"✓ Schema registry created with {len(schema_registry)} table schemas")

# %%
# def enforce_schema(df, table_name):
#     """
#     Enforce schema on a DataFrame based on the registered schema.
#     Compatible with Serverless compute (no RDD operations).

#     Example usage:
#         # Assume you have a DataFrame 'raw_df' and want to enforce the schema for 'humanresources.department'
#         enforced_df = enforce_schema(raw_df, "humanresources.department")
#         display(enforced_df)

#     Args:
#         df: Input DataFrame
#         table_name: Table name (e.g., 'humanresources.department' or 'DimCustomer')

#     Returns:
#         DataFrame with enforced schema
#     """
#     table_key = table_name.lower()

#     if table_key not in schema_registry:
#         raise ValueError(f"Schema not found for table: {table_name}. Available tables: {list(schema_registry.keys())}")

#     target_schema = schema_registry[table_key]
    
#     # Build column expressions for each field in the target schema
#     select_exprs = []
#     source_cols = {c.lower(): c for c in df.columns}  # Map lowercase to actual column names
    
#     for field in target_schema.fields:
#         field_name_lower = field.name.lower()
        
#         # Check if column exists in source (case-insensitive)
#         if field_name_lower in source_cols:
#             source_col_name = source_cols[field_name_lower]
#             # Cast to target type and alias to target name
#             select_exprs.append(col(source_col_name).cast(field.dataType).alias(field.name))
#         else:
#             # Column missing - add null with correct type
#             select_exprs.append(lit(None).cast(field.dataType).alias(field.name))
    
#     # Apply schema transformation
#     return df.select(select_exprs)


# def validate_schema(df, table_name):
#     """
#     Validate if a DataFrame matches the expected schema.
    
#     Args:
#         df: Input DataFrame
#         table_name: Table name
    
#     Returns:
#         Tuple (is_valid: bool, differences: list)
#     """
#     table_key = table_name.lower()
    
#     if table_key not in schema_registry:
#         return False, [f"Schema not found for table: {table_name}"]
    
#     expected_schema = schema_registry[table_key]
#     actual_schema = df.schema
    
#     differences = []
    
#     # Check field count
#     if len(expected_schema.fields) != len(actual_schema.fields):
#         differences.append(f"Field count mismatch: expected {len(expected_schema.fields)}, got {len(actual_schema.fields)}")
    
#     # Check each field
#     expected_fields = {f.name: f for f in expected_schema.fields}
#     actual_fields = {f.name: f for f in actual_schema.fields}
    
#     for field_name, expected_field in expected_fields.items():
#         if field_name not in actual_fields:
#             differences.append(f"Missing field: {field_name}")
#         else:
#             actual_field = actual_fields[field_name]
#             if expected_field.dataType != actual_field.dataType:
#                 differences.append(f"Type mismatch for {field_name}: expected {expected_field.dataType}, got {actual_field.dataType}")
#             if expected_field.nullable != actual_field.nullable:
#                 differences.append(f"Nullable mismatch for {field_name}: expected {expected_field.nullable}, got {actual_field.nullable}")
    
#     for field_name in actual_fields:
#         if field_name not in expected_fields:
#             differences.append(f"Extra field: {field_name}")
    
#     return len(differences) == 0, differences


# def get_schema(table_name):
#     """
#     Get the registered schema for a table.
    
#     Args:
#         table_name: Table name
    
#     Returns:
#         StructType schema
#     """
#     table_key = table_name.lower()
    
#     if table_key not in schema_registry:
#         raise ValueError(f"Schema not found for table: {table_name}. Available tables: {list(schema_registry.keys())}")
    
#     return schema_registry[table_key]


# def create_table_with_schema(catalog, schema_name, table_name, location=None):
#     """
#     Create a Delta table with enforced schema.
    
#     Args:
#         catalog: Catalog name
#         schema_name: Schema name
#         table_name: Table name (short name, e.g., 'department')
#         location: Optional storage location
    
#     Returns:
#         Full table path
#     """
#     full_table = f"{catalog}.{schema_name}.{table_name}"
#     table_key = f"{schema_name}.{table_name}".lower()
    
#     if table_key not in schema_registry:
#         raise ValueError(f"Schema not found for {table_key}")
    
#     schema = schema_registry[table_key]
    
#     # Create empty DataFrame with schema
#     empty_df = spark.createDataFrame([], schema)
    
#     # Create Delta table
#     writer = empty_df.write.format("delta").mode("overwrite")
    
#     if location:
#         writer = writer.option("path", location)
    
#     writer.saveAsTable(full_table)
    
#     # Enable schema enforcement and evolution settings
#     spark.sql(f"""
#         ALTER TABLE {full_table} 
#         SET TBLPROPERTIES (
#             'delta.columnMapping.mode' = 'name',
#             'delta.minReaderVersion' = '2',
#             'delta.minWriterVersion' = '5'
#         )
#     """)
    
#     return full_table


# print("✓ Schema enforcement utilities ready (Serverless-compatible)")
# print("\nAvailable functions:")
# print("  - enforce_schema(df, table_name): Apply schema to DataFrame")
# print("  - validate_schema(df, table_name): Check if DataFrame matches schema")
# print("  - get_schema(table_name): Get schema for a table")
# print("  - create_table_with_schema(catalog, schema, table, location): Create Delta table with schema")
